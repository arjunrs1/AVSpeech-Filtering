# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("output.csv")

# %%
(len(data[data.confidence_score_0>0.75])/len(data))*123841
# Out:
# 33178.585669781925

# %%
mic_vis_q = data[data.confidence_score_0>0.75]

# %%
mic_vis_yes = mic_vis_q[mic_vis_q.answer_0=="yes"]
mic_vis_no = mic_vis_q[mic_vis_q.answer_0=="no"]

# %%
mic_vis_yes
# Out:
#     image_filename answer_0 answer_1 answer_2 answer_3 answer_4 answer_5  \
# 256       9449.png      yes      yes      yes       no      yes       no
# 284      96704.png      yes       no      yes      yes      yes       no
#
#     answer_6 answer_7  confidence_score_0  confidence_score_1  \
# 256       no       no            0.772000            0.902527
# 284       no       no            0.783904            0.953571
#
#      confidence_score_2  confidence_score_3  confidence_score_4  \
# 256            0.831015            0.832723            0.423357
# 284            0.945098            0.762521            0.483863
#
#      confidence_score_5  confidence_score_6  confidence_score_7
# 256            0.921879            0.960743            0.887448
# 284            0.995825            0.996893            0.947012

# %%
mic_vis_no
# Out:
#     image_filename answer_0 answer_1 answer_2 answer_3 answer_4 answer_5  \
# 0        64253.png       no      yes      yes       no      yes       no
# 27       67479.png       no       no      yes       no       no       no
# 31       67667.png       no       no      yes       no      yes       no
# 39       69058.png       no       no      yes       no      yes       no
# 40       69297.png       no       no      yes       no       no       no
# ..             ...      ...      ...      ...      ...      ...      ...
# 303       9730.png       no       no      yes       no      yes       no
# 309      98459.png       no       no      yes       no       no       no
# 310      98473.png       no       no      yes      yes      yes       no
# 315      98880.png       no       no      yes       no       no       no
# 319      99951.png       no       no      yes       no       no       no
#
#     answer_6 answer_7  confidence_score_0  confidence_score_1  \
# ...
